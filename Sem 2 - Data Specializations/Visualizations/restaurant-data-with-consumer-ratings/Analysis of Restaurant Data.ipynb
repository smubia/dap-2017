# %% [markdown]
# # Analysis of Restaurant Data
# ## Goals
# - To identify the top 50 restraunts within this dataset
# - To see which locations/countries have the best rated restaurants
# - To see what are the most common cuisines offered
# - To see what are the most common payment methods
# - Reviewer demographic breakdown & preference analysis
#     - What kind of restaurants do the different drinking types go to?
#     - Do reviewers of certain age ranges have a tendency to rate a restaurant differently?
#     - Does a reviewer's budget level influence the ratings of restraunts?
#     - How much influence does a reviewer's interest have on their choice of restraunt?
#     - To what extend does a reviewer's marital status affect which restraunts they go to?
#
# ## List of CSVs
# ### Restaurants
# 1. chefmozaccepts.csv
# 2. chefmozcuisine.csv
# 3. chefmozhours4.csv
# 4. chefmozparking.csv
# 5. geoplaces2.csv
#
# ### Consumers
# 6. usercuisine.csv
# 7. userpayment.csv
# 8. userprofile.csv
#
# ### User-Item-Rating
# 9. rating_final.csv

# %% [markdown]
# # Find the Top 50 Restaurants
# We'll use the `rating_final.csv` for user ratings, and the `geoplaces2.csv` for restaurant information.

# %%
import pandas as pd
import numpy as np
import pprint
import seaborn as sns

# %%
rating_final_df = pd.read_csv('./data/rating_final.csv')
print(rating_final_df.dtypes)
# Out:
# userID            object
# placeID            int64
# rating             int64
# food_rating        int64
# service_rating     int64
# dtype: object

# %%
geoplaces2_df = pd.read_csv('./data/geoplaces2.csv')
print(geoplaces2_df.dtypes)
# Out:
# placeID             int64
# latitude          float64
# longitude         float64
# the_geom_meter     object
# name               object
# address            object
# city               object
# state              object
# country            object
# fax                object
# zip                object
# alcohol            object
# smoking_area       object
# dress_code         object
# accessibility      object
# price              object
# url                object
# Rambience          object
# franchise          object
# area               object
# other_services     object
# dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = rating_final_df.merge(
    geoplaces2_df, 
    on=('placeID'), 
    how='inner', 
    suffixes=('_rating', '_geo' ))
df.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating   latitude  longitude  \
# 0  U1077   135085       2            2               2  22.150802 -100.98268
# 1  U1108   135085       1            2               1  22.150802 -100.98268
# 2  U1081   135085       1            2               1  22.150802 -100.98268
# 3  U1056   135085       2            2               2  22.150802 -100.98268
# 4  U1134   135085       2            1               2  22.150802 -100.98268
#
#                                       the_geom_meter                    name  \
# 0  0101000020957F00009F823DA6094858C18A2D4D37F9A4...  Tortas Locas Hipocampo
# 1  0101000020957F00009F823DA6094858C18A2D4D37F9A4...  Tortas Locas Hipocampo
# 2  0101000020957F00009F823DA6094858C18A2D4D37F9A4...  Tortas Locas Hipocampo
# 3  0101000020957F00009F823DA6094858C18A2D4D37F9A4...  Tortas Locas Hipocampo
# 4  0101000020957F00009F823DA6094858C18A2D4D37F9A4...  Tortas Locas Hipocampo
#
#                           address      ...                  alcohol  \
# 0  Venustiano Carranza 719 Centro      ...        No_Alcohol_Served
# 1  Venustiano Carranza 719 Centro      ...        No_Alcohol_Served
# 2  Venustiano Carranza 719 Centro      ...        No_Alcohol_Served
# 3  Venustiano Carranza 719 Centro      ...        No_Alcohol_Served
# 4  Venustiano Carranza 719 Centro      ...        No_Alcohol_Served
#
#     smoking_area dress_code     accessibility   price url Rambience franchise  \
# 0  not permitted   informal  no_accessibility  medium   ?  familiar         f
# 1  not permitted   informal  no_accessibility  medium   ?  familiar         f
# 2  not permitted   informal  no_accessibility  medium   ?  familiar         f
# 3  not permitted   informal  no_accessibility  medium   ?  familiar         f
# 4  not permitted   informal  no_accessibility  medium   ?  familiar         f
#
#      area other_services
# 0  closed           none
# 1  closed           none
# 2  closed           none
# 3  closed           none
# 4  closed           none
#
# [5 rows x 25 columns]

# %%
df.shape #prints the shape of the dataframe
# Out:
# (1161, 25)

# %%
df.drop(['the_geom_meter', 'url', 'address', 'zip', 'fax'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating   latitude  longitude  \
# 0  U1077   135085       2            2               2  22.150802 -100.98268
# 1  U1108   135085       1            2               1  22.150802 -100.98268
# 2  U1081   135085       1            2               1  22.150802 -100.98268
# 3  U1056   135085       2            2               2  22.150802 -100.98268
# 4  U1134   135085       2            1               2  22.150802 -100.98268
#
#                      name             city state country            alcohol  \
# 0  Tortas Locas Hipocampo  San Luis Potosi   SLP  Mexico  No_Alcohol_Served
# 1  Tortas Locas Hipocampo  San Luis Potosi   SLP  Mexico  No_Alcohol_Served
# 2  Tortas Locas Hipocampo  San Luis Potosi   SLP  Mexico  No_Alcohol_Served
# 3  Tortas Locas Hipocampo  San Luis Potosi   SLP  Mexico  No_Alcohol_Served
# 4  Tortas Locas Hipocampo  San Luis Potosi   SLP  Mexico  No_Alcohol_Served
#
#     smoking_area dress_code     accessibility   price Rambience franchise  \
# 0  not permitted   informal  no_accessibility  medium  familiar         f
# 1  not permitted   informal  no_accessibility  medium  familiar         f
# 2  not permitted   informal  no_accessibility  medium  familiar         f
# 3  not permitted   informal  no_accessibility  medium  familiar         f
# 4  not permitted   informal  no_accessibility  medium  familiar         f
#
#      area other_services
# 0  closed           none
# 1  closed           none
# 2  closed           none
# 3  closed           none
# 4  closed           none

# %% [markdown]
# Since `rating`, `food_rating` and `service_rating` are based on a 2 point scale, we'll re-scale it to 5 so that the aggregated ratings will be out of 5.00 and make it easier for users of the visualization.

# %%
df['rating'] = df['rating'] * (5/2)
df['food_rating'] = df['food_rating'] * (5/2)
df['service_rating'] = df['service_rating'] * (5/2)
df.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating   latitude  longitude  \
# 0  U1077   135085     5.0          5.0             5.0  22.150802 -100.98268
# 1  U1108   135085     2.5          5.0             2.5  22.150802 -100.98268
# 2  U1081   135085     2.5          5.0             2.5  22.150802 -100.98268
# 3  U1056   135085     5.0          5.0             5.0  22.150802 -100.98268
# 4  U1134   135085     5.0          2.5             5.0  22.150802 -100.98268
#
#                      name             city state country            alcohol  \
# 0  Tortas Locas Hipocampo  San Luis Potosi   SLP  Mexico  No_Alcohol_Served
# 1  Tortas Locas Hipocampo  San Luis Potosi   SLP  Mexico  No_Alcohol_Served
# 2  Tortas Locas Hipocampo  San Luis Potosi   SLP  Mexico  No_Alcohol_Served
# 3  Tortas Locas Hipocampo  San Luis Potosi   SLP  Mexico  No_Alcohol_Served
# 4  Tortas Locas Hipocampo  San Luis Potosi   SLP  Mexico  No_Alcohol_Served
#
#     smoking_area dress_code     accessibility   price Rambience franchise  \
# 0  not permitted   informal  no_accessibility  medium  familiar         f
# 1  not permitted   informal  no_accessibility  medium  familiar         f
# 2  not permitted   informal  no_accessibility  medium  familiar         f
# 3  not permitted   informal  no_accessibility  medium  familiar         f
# 4  not permitted   informal  no_accessibility  medium  familiar         f
#
#      area other_services
# 0  closed           none
# 1  closed           none
# 2  closed           none
# 3  closed           none
# 4  closed           none

# %%
#Check how lopsided each column is
df.country.unique()
# Out:
# array(['Mexico', 'mexico', '?'], dtype=object)

# %%
df.state.unique()
# Out:
# array(['SLP', 's.l.p.', '?', 'Tamaulipas', 'tamaulipas', 'Morelos',
#        'San Luis Potosi', 'morelos', 'S.L.P.', 'san luis potosi', 'slp',
#        'mexico', 'san luis potos'], dtype=object)

# %% [markdown]
# ## Sorting by the different ratings
# In order to figure out which is the most favourite by users, we have to sort the restraunts by the means of `rating`, `food_rating`, and `service_rating` columns.

# %% [markdown]
# First, we prepare dataframe to show ratings.
# We re-order the column names, removing those that will be aggregated, and then use this list of columns as a basis to group our dataframe

# %%
columns = list(df)
columns = [i for i in columns if i not in (
    'placeID',
    'userID',
    'food_rating',
    'service_rating',
    'rating')]
columns.insert(0, 'placeID')

# %%
agg_groupby = df.groupby(columns, as_index=False).agg({
    'userID': 'count',
    'rating': 'mean',
    'food_rating': 'mean',
    'service_rating': 'mean',
}).rename(index=str, columns={
    'userID': 'userID_count',
    'rating': 'rating_mean',
    'food_rating': 'food_rating_mean',
    'service_rating': 'service_rating_mean'})
agg_groupby
# Out:
#      placeID   latitude   longitude                                     name  \
# 0     132560  23.752304  -99.166913                       puesto de gorditas
# 1     132561  23.726819  -99.126506                               cafe ambar
# 2     132564  23.730925  -99.145185                                  churchs
# 3     132572  22.141647 -100.992712                             Cafe Chaires
# 4     132583  18.922290  -99.234332                         McDonalds Centro
# 5     132584  23.752365  -99.165288                       Gorditas Dona Tota
# 6     132594  23.752168  -99.165709       tacos de barbacoa enfrente del Tec
# 7     132608  23.758805  -99.165130                   Hamburguesas La perica
# 8     132609  23.760268  -99.165865                 Pollo_Frito_Buenos_Aires
# 9     132613  23.752903  -99.165076                            carnitas_mata
# 10    132626  23.737583  -99.135132                    la perica hamburguesa
# 11    132630  23.752930  -99.164473                               palomo tec
# 12    132654  23.735523  -99.129588    Carnitas Mata  Calle 16 de Septiembre
# 13    132660  23.752943  -99.164679    carnitas mata calle Emilio Portes Gil
# 14    132663  23.752511  -99.166954                                tacos abi
# 15    132665  23.736798  -99.134241                       TACOS CORRECAMINOS
# 16    132667  23.752697  -99.163359           little pizza Emilio Portes Gil
# 17    132668  23.738212  -99.151955                           TACOS EL GUERO
# 18    132706  23.729216  -99.132357                       Gorditas Dona Tota
# 19    132715  23.732423  -99.158660                     tacos de la estacion
# 20    132717  23.731860  -99.150436                             tortas hawai
# 21    132723  22.148934 -101.019845                        Gordas de morales
# 22    132732  23.754357  -99.171288                       Taqueria EL amigo
# 23    132733  23.752707  -99.162565                            Little Cesarz
# 24    132740  23.752197  -99.166632            Carreton de Flautas y Migadas
# 25    132754  22.147738 -100.990616                          Cabana Huasteca
# 26    132755  22.153324 -101.019546                     La Estrella de Dimas
# 27    132766  18.910178  -99.231544                                   Mikasa
# 28    132767  18.882087  -99.163027             Restaurant Familiar El Chino
# 29    132768  18.925773  -99.232636                       Mariscos Tia Licha
# ..       ...        ...         ...                                      ...
# 100   135054  22.140626 -100.915657         Restaurante y Pescaderia Tampico
# 101   135055  22.148854 -101.008472  la Cochinita Pibil Restaurante Yucateco
# 102   135057  22.145992 -100.955118         El Herradero Restaurante and Bar
# 103   135058  22.165587 -101.001273                     Restaurante Tiberius
# 104   135059  22.145108 -100.989547     Restaurant Bar Hacienda los Martinez
# 105   135060  22.156883 -100.978485                  Restaurante Marisco Sam
# 106   135062  22.153703 -100.979033            Restaurante El Cielo Potosino
# 107   135063  22.156724 -100.975556                    Restaurante Alhondiga
# 108   135064  22.154687 -100.996617      Restaurante El Chivero S.A. de C.V.
# 109   135065  22.149580 -100.999557                     El angel Restaurante
# 110   135066  22.168350 -100.972466                       Restaurante Guerra
# 111   135069  22.140129 -100.944872                Abondance Restaurante Bar
# 112   135070  22.152918 -100.915164                           Restaurante 75
# 113   135071  22.126375 -100.910926                   Restaurante la Cantina
# 114   135072  22.149192 -101.002936                               Sushi Itto
# 115   135073  22.147175 -100.974269             Restaurante Bar El Gallinero
# 116   135074  22.149689 -100.999525        Restaurante la Parroquia Potosina
# 117   135075  22.139573 -100.991564                     Mariscos El Pescador
# 118   135076  22.181017 -100.973614                Restaurante Pueblo Bonito
# 119   135079  22.156376 -100.998355                               Koye Sushi
# 120   135080  22.145008 -100.997969                              los Toneles
# 121   135081  22.164842 -100.960493                                  El Club
# 122   135082  22.151448 -100.915099                     la Estrella de Dimas
# 123   135085  22.150802 -100.982680                   Tortas Locas Hipocampo
# 124   135086  22.141421 -101.013955              Mcdonalds Parque Tangamanga
# 125   135088  18.876011  -99.219890                        Cafeteria cenidet
# 126   135104  23.752982  -99.168434                                     vips
# 127   135106  22.149709 -100.976093               El Rinc�n de San Francisco
# 128   135108  22.136253 -100.933585                               Potzocalli
# 129   135109  18.921785  -99.235350                                Paniroles
#
#                 city            state country            alcohol  \
# 0           victoria       tamaulipas  mexico  No_Alcohol_Served
# 1                  ?                ?       ?  No_Alcohol_Served
# 2                  ?                ?       ?  No_Alcohol_Served
# 3    San Luis Potosi  San Luis Potosi  Mexico  No_Alcohol_Served
# 4         Cuernavaca          Morelos  Mexico  No_Alcohol_Served
# 5                  ?                ?       ?  No_Alcohol_Served
# 6                  ?                ?       ?  No_Alcohol_Served
# 7           victoria       Tamaulipas  Mexico  No_Alcohol_Served
# 8           victoria       Tamaulipas  Mexico  No_Alcohol_Served
# 9           victoria       Tamaulipas  Mexico  No_Alcohol_Served
# 10          victoria       tamaulipas       ?  No_Alcohol_Served
# 11          victoria       tamaulipas       ?  No_Alcohol_Served
# 12         victoria        tamaulipas       ?  No_Alcohol_Served
# 13          victoria       tamaulipas       ?  No_Alcohol_Served
# 14          victoria       tamaulipas  mexico  No_Alcohol_Served
# 15          victoria       tamaulipas  mexico  No_Alcohol_Served
# 16         victoria        tamaulipas       ?  No_Alcohol_Served
# 17          victoria       tamaulipas  mexico  No_Alcohol_Served
# 18      Cd. Victoria       Tamaulipas  Mexico  No_Alcohol_Served
# 19                 ?                ?       ?  No_Alcohol_Served
# 20                 ?                ?       ?  No_Alcohol_Served
# 21                 ?  San Luis Potosi  Mexico           Full_Bar
# 22       Cd Victoria       Tamaulipas  Mexico  No_Alcohol_Served
# 23   Ciudad Victoria       Tamaulipas  Mexico  No_Alcohol_Served
# 24   Ciudad Victoria       Tamaulipas  Mexico  No_Alcohol_Served
# 25   San Luis Potosi           S.L.P.  Mexico  No_Alcohol_Served
# 26   San Luis Potosi           S.L.P.  Mexico  No_Alcohol_Served
# 27        Cuernavaca          Morelos  Mexico          Wine-Beer
# 28          Jiutepec          Morelos       ?          Wine-Beer
# 29        cuernavaca          morelos  mexico  No_Alcohol_Served
# ..               ...              ...     ...                ...
# 100  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 101  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 102  San Luis Potosi              SLP  Mexico          Wine-Beer
# 103  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 104  San Luis Potosi              SLP  Mexico          Wine-Beer
# 105  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 106  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 107  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 108  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 109  San Luis Potosi              SLP  Mexico          Wine-Beer
# 110  San Luis Potosi              SLP  Mexico          Wine-Beer
# 111  San Luis Potosi              SLP  Mexico          Wine-Beer
# 112  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 113  San Luis Potosi              SLP  Mexico           Full_Bar
# 114  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 115  San Luis Potosi              SLP  Mexico          Wine-Beer
# 116  San Luis Potosi              SLP  Mexico          Wine-Beer
# 117  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 118  San Luis Potosi              SLP  Mexico          Wine-Beer
# 119  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 120  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 121  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 122  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 123  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 124  San Luis Potosi              SLP  Mexico  No_Alcohol_Served
# 125       Cuernavaca          Morelos  Mexico  No_Alcohol_Served
# 126                ?                ?       ?           Full_Bar
# 127  San Luis Potosi  San Luis Potosi  Mexico          Wine-Beer
# 128  San Luis Potosi                ?       ?  No_Alcohol_Served
# 129                ?                ?       ?          Wine-Beer
#
#       smoking_area dress_code     accessibility   price Rambience franchise  \
# 0        permitted   informal  no_accessibility     low  familiar         f
# 1             none   informal        completely     low  familiar         f
# 2             none   informal        completely     low  familiar         f
# 3    not permitted   informal        completely     low  familiar         f
# 4    not permitted   informal         partially     low  familiar         t
# 5    not permitted   informal        completely  medium  familiar         t
# 6    not permitted   informal        completely     low  familiar         f
# 7        permitted   informal        completely     low     quiet         t
# 8    not permitted   informal        completely     low     quiet         t
# 9        permitted   informal        completely  medium  familiar         t
# 10            none   informal        completely  medium  familiar         t
# 11            none   informal        completely     low  familiar         f
# 12            none   informal        completely     low  familiar         f
# 13            none   informal        completely     low  familiar         f
# 14            none   informal        completely     low  familiar         f
# 15            none   informal        completely     low  familiar         f
# 16            none   informal        completely     low  familiar         t
# 17            none   informal        completely     low  familiar         f
# 18   not permitted   informal  no_accessibility  medium  familiar         t
# 19            none   informal  no_accessibility     low     quiet         f
# 20   not permitted   informal         partially  medium  familiar         f
# 21         section   informal        completely  medium  familiar         f
# 22            none     casual        completely     low  familiar         f
# 23   not permitted   informal        completely  medium  familiar         t
# 24       permitted   informal        completely     low  familiar         f
# 25            none   informal         partially  medium  familiar         f
# 26            none   informal         partially  medium  familiar         f
# 27            none   informal  no_accessibility  medium  familiar         f
# 28       permitted     casual         partially  medium  familiar         f
# 29   not permitted     casual         partially  medium  familiar         t
# ..             ...        ...               ...     ...       ...       ...
# 100           none   informal  no_accessibility    high  familiar         f
# 101        section   informal  no_accessibility    high  familiar         f
# 102        section   informal  no_accessibility  medium  familiar         f
# 103           none   informal  no_accessibility  medium  familiar         t
# 104        section   informal  no_accessibility  medium  familiar         f
# 105           none   informal  no_accessibility  medium  familiar         f
# 106           none   informal  no_accessibility  medium  familiar         f
# 107           none   informal  no_accessibility  medium  familiar         f
# 108           none   informal  no_accessibility    high  familiar         f
# 109        section   informal  no_accessibility    high  familiar         f
# 110        section   informal  no_accessibility    high  familiar         f
# 111           none   informal  no_accessibility     low  familiar         f
# 112           none   informal  no_accessibility  medium  familiar         f
# 113        section   informal  no_accessibility  medium  familiar         f
# 114           none   informal  no_accessibility  medium  familiar         f
# 115        section   informal  no_accessibility    high  familiar         f
# 116        section   informal  no_accessibility    high  familiar         f
# 117           none   informal  no_accessibility  medium  familiar         f
# 118           none   informal  no_accessibility    high  familiar         f
# 119           none   informal  no_accessibility    high  familiar         f
# 120        section   informal  no_accessibility    high  familiar         f
# 121           none   informal  no_accessibility  medium  familiar         f
# 122           none   informal  no_accessibility  medium  familiar         f
# 123  not permitted   informal  no_accessibility  medium  familiar         f
# 124  not permitted   informal  no_accessibility  medium  familiar         t
# 125  not permitted   informal  no_accessibility     low     quiet         f
# 126  not permitted   informal        completely  medium  familiar         t
# 127    only at bar   informal         partially  medium  familiar         f
# 128           none   informal        completely     low  familiar         f
# 129  not permitted   informal  no_accessibility  medium     quiet         f
#
#        area other_services  userID_count  rating_mean  food_rating_mean  \
# 0      open           none             4     1.250000          2.500000
# 1    closed           none             4     1.875000          2.500000
# 2    closed           none             4     3.125000          3.125000
# 3    closed           none            15     2.500000          2.500000
# 4    closed           none             4     2.500000          2.500000
# 5    closed           none             6     3.333333          3.750000
# 6      open           none             5     1.500000          3.000000
# 7      open           none             6     2.500000          2.916667
# 8    closed           none             5     1.500000          1.500000
# 9    closed           none             6     2.916667          3.333333
# 10   closed           none             4     3.125000          2.500000
# 11   closed           none             6     2.916667          2.916667
# 12   closed           none             4     0.625000          0.625000
# 13   closed           none             5     3.500000          3.500000
# 14   closed           none             6     1.250000          1.250000
# 15   closed           none             5     2.000000          2.000000
# 16   closed           none             4     3.125000          5.000000
# 17   closed           none             3     2.500000          2.500000
# 18   closed           none             4     1.875000          3.125000
# 19     open           none             4     2.500000          2.500000
# 20   closed           none             3     3.333333          3.333333
# 21   closed           none            12     3.541667          3.333333
# 22     open           none             8     1.562500          2.187500
# 23   closed           none            10     3.250000          3.250000
# 24     open           none             8     1.875000          3.125000
# 25   closed           none            13     3.653846          3.653846
# 26   closed        variety             5     4.500000          5.000000
# 27   closed           none             3     1.666667          2.500000
# 28     open        variety             6     2.916667          3.333333
# 29   closed           none            10     4.000000          4.250000
# ..      ...            ...           ...          ...               ...
# 100  closed           none            10     2.500000          2.250000
# 101  closed           none             7     4.285714          4.285714
# 102  closed           none            15     3.166667          3.333333
# 103  closed           none            18     2.777778          2.500000
# 104  closed           none             9     4.166667          3.611111
# 105  closed           none            22     2.840909          2.613636
# 106  closed           none            21     3.095238          3.095238
# 107  closed           none             8     3.125000          2.500000
# 108  closed           none            17     2.205882          2.647059
# 109  closed           none             9     2.777778          2.777778
# 110  closed           none            12     3.750000          2.500000
# 111  closed           none            12     1.250000          1.250000
# 112  closed           none             8     2.187500          2.500000
# 113  closed           none             9     2.500000          1.944444
# 114  closed           none             8     3.125000          3.437500
# 115  closed           none             4     3.750000          3.750000
# 116  closed           none             4     4.375000          4.375000
# 117  closed           none            13     4.230769          4.230769
# 118  closed           none            13     3.269231          3.846154
# 119  closed           none            17     2.941176          2.794118
# 120  closed           none             6     2.500000          2.500000
# 121  closed           none            11     2.954545          3.636364
# 122  closed           none             9     1.944444          1.944444
# 123  closed           none            36     3.333333          3.680556
# 124  closed           none            10     2.000000          1.500000
# 125  closed           none             6     2.500000          2.916667
# 126  closed        variety             7     2.142857          3.571429
# 127    open           none            10     3.000000          3.000000
# 128  closed           none            11     2.954545          2.954545
# 129  closed       Internet             4     2.500000          3.125000
#
#      service_rating_mean
# 0               0.625000
# 1               2.500000
# 2               3.750000
# 3               2.333333
# 4               3.125000
# 5               2.500000
# 6               1.500000
# 7               2.083333
# 8               1.500000
# 9               2.500000
# 10              2.500000
# 11              2.500000
# 12              0.625000
# 13              2.500000
# 14              1.666667
# 15              2.500000
# 16              3.125000
# 17              2.500000
# 18              2.500000
# 19              1.250000
# 20              2.500000
# 21              3.125000
# 22              2.500000
# 23              3.000000
# 24              1.562500
# 25              3.269231
# 26              4.000000
# 27              1.666667
# 28              2.916667
# 29              3.500000
# ..                   ...
# 100             2.500000
# 101             4.285714
# 102             3.333333
# 103             2.500000
# 104             3.333333
# 105             3.181818
# 106             2.738095
# 107             3.125000
# 108             1.764706
# 109             2.222222
# 110             3.333333
# 111             1.875000
# 112             1.875000
# 113             1.944444
# 114             3.125000
# 115             2.500000
# 116             4.375000
# 117             3.653846
# 118             2.692308
# 119             2.352941
# 120             2.500000
# 121             3.181818
# 122             1.666667
# 123             2.916667
# 124             2.000000
# 125             2.500000
# 126             2.142857
# 127             3.000000
# 128             2.500000
# 129             1.875000
#
# [130 rows x 20 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot( agg_groupby["rating_mean"] , color="skyblue", label="Overall Rating")
sns.distplot( agg_groupby["food_rating_mean"] , color="limegreen", label="Food Rating")
sns.distplot( agg_groupby["service_rating_mean"] , color="pink", label="Service Rating")
sns.plt.legend()
sns.plt.show()

# %%
import seaborn as sns
f, axes = plt.subplots(3,1, figsize=(8,8), sharex=True)
sns.distplot( agg_groupby["rating_mean"] , color="skyblue", ax=axes[0])
sns.distplot( agg_groupby["food_rating_mean"] , color="limegreen", ax=axes[1])
sns.distplot( agg_groupby["service_rating_mean"] , color="red", ax=axes[2])
sns.plt.show()

# %%
sns.lmplot( x="food_rating_mean", y="service_rating_mean", data=agg_groupby, \
           fit_reg=True, hue='price', legend=False, \
          markers=["o", "x", "1"])
plt.legend(loc='lower right')

sns.plt.show()

# %%
sns.lmplot( x="food_rating_mean", y="service_rating_mean", data=agg_groupby, \
           fit_reg=True, hue='franchise', legend=False, \
          markers=["x", "o"])
plt.legend(loc='lower right')

sns.plt.show()

# %%
sns.lmplot( x="food_rating_mean", y="service_rating_mean", data=agg_groupby, \
           fit_reg=True, hue='dress_code', legend=False, \
          markers=["x", "o", "1"])
plt.legend(loc='lower right')

sns.plt.show()

# %% [markdown]
# ## Visualizing the Top 20 Restaurants by Overall Ratings
# We prepare a map to visualize where exactly our top 20 restaurants are located.
#
# For this, we will be using the folium python package.

# %%
# We create the dataframe with the overall ratings, with the rating_mean descending
by_overall = agg_groupby.sort_values(['rating_mean'], ascending=False)
by_overall.head(n=5)
# Out:
#     placeID   latitude   longitude                        name  \
# 57   132955  22.147622 -101.010275                   emilianos
# 82   135034  22.140517 -101.021422  Michiko Restaurant Japones
# 62   134986  18.928798  -99.239513    Restaurant Las Mananitas
# 52   132922  22.151135 -100.982311        cafe punta del cielo
# 26   132755  22.153324 -101.019546        La Estrella de Dimas
#
#                city    state country            alcohol smoking_area  \
# 57   san luis potos   mexico       ?          Wine-Beer         none
# 82  San Luis Potosi      SLP  Mexico  No_Alcohol_Served         none
# 62       Cuernavaca  Morelos  Mexico          Wine-Beer         none
# 52                ?        ?       ?  No_Alcohol_Served    permitted
# 26  San Luis Potosi   S.L.P.  Mexico  No_Alcohol_Served         none
#
#    dress_code     accessibility   price Rambience franchise    area  \
# 57   informal        completely     low  familiar         t  closed
# 82   informal  no_accessibility  medium  familiar         f  closed
# 62     formal  no_accessibility    high  familiar         f  closed
# 52     formal        completely  medium  familiar         f  closed
# 26   informal         partially  medium  familiar         f  closed
#
#    other_services  userID_count  rating_mean  food_rating_mean  \
# 57        variety             5     5.000000              4.50
# 82           none             5     5.000000              5.00
# 62           none             8     5.000000              5.00
# 52           none             6     4.583333              3.75
# 26        variety             5     4.500000              5.00
#
#     service_rating_mean
# 57             4.500000
# 82             4.000000
# 62             5.000000
# 52             4.583333
# 26             4.000000

# %%
import folium

# %%
#list of lat longs
by_overall_20 = by_overall.head(n=20)
by_overall_20_lat_long = by_overall_20[['latitude','longitude']]
by_overall_20_lat_long_arr = by_overall_20_lat_long.values
by_overall_20_lat_long_list = by_overall_20_lat_long_arr.tolist()
by_overall_20_lat_long_list
# Out:
# [[22.147622, -101.01027490000001],
#  [22.140517000000003, -101.021422],
#  [18.928798, -99.239513],
#  [22.1511348, -100.9823115],
#  [22.153323999999998, -101.0195459],
#  [18.917441, -99.165945],
#  [18.916654, -99.22711],
#  [22.149689000000002, -100.999525],
#  [22.148854, -101.008472],
#  [22.139573000000002, -100.991564],
#  [22.14955, -100.97797],
#  [22.145108, -100.989547],
#  [18.940828, -99.21542600000001],
#  [22.1449787, -101.0056829],
#  [18.9257734, -99.2326355],
#  [18.915421, -99.184871],
#  [22.147879999999997, -100.98947199999999],
#  [18.923429000000002, -99.216413],
#  [22.146658, -100.987219],
#  [22.147175, -100.97426899999999]]

# %%
# We first define the folium map
overall_ratings_map = folium.Map();

overall_ratings_map.fit_bounds(bounds=by_overall_20_lat_long_list)

# We define a function to add our marker to the map
def add_marker(lat,long,map, label=None, color=None):
    """Adds a marker to the specified map"""
    folium.Marker([lat,long],
                 popup=label,
                 icon=folium.Icon(color=color, icon='heart')).add_to(map)

# Let's see what this map looks like so far
overall_ratings_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok it doesn't really look like much, but we're going to add the markers to it now!

# %% [markdown]
# Let's loop over the 20 restaurants ranked by overall rating to visualize their locations!
# We add a marker to the map for each restaurant.
# We also add a clickable label for each marker, and add an appropriate description to each.

# %%
by_overall_top_5 = by_overall.head(n=5)['placeID'].tolist()
by_overall_top_10 = by_overall.head(n=10)['placeID'].tolist()
by_overall_6_to_10 = [x for x in by_overall_top_10 if (x not in by_overall_top_5)]
by_overall_6_to_10
# Out:
# [135013, 134976, 135074, 135055, 135075]

# %%
for index, row in by_overall_20.iterrows():
    rating = '%.2f' % row['rating_mean'] #format to 2dp
    if row['placeID'] in by_overall_top_5:
        add_marker(row['latitude'], row['longitude'],overall_ratings_map, 
                   label='<b>{}</b><br>rating: {} / 5<br>{}'.format(row['name'], rating, 'Top 5'),
                  color='lightblue')
    elif row['placeID'] in by_overall_top_10:
        add_marker(row['latitude'], row['longitude'],overall_ratings_map, 
               label='<b>{}</b><br>rating: {} / 5<br>{}'.format(row['name'], rating, 'Top 10'),
                  color='blue')
    else:
        add_marker(row['latitude'], row['longitude'],overall_ratings_map, 
               label='<b>{}</b><br>rating: {} / 5<br>{}'.format(row['name'], rating, 'Top 20'),
                color='darkblue')
overall_ratings_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Visualizing the Top 20 Restaurants by Food Rating
# We sort the restraunts now by `food_rating_mean`, but we also use `rating_mean` as a secondary sort key to ensure that restaurants with the same `food_rating_mean` will be appropriately ranked.

# %%
by_food = agg_groupby.sort_values(['food_rating_mean', 'rating_mean'], ascending=False)
by_food.head(n=5)
# Out:
#     placeID   latitude   longitude                            name  \
# 62   134986  18.928798  -99.239513        Restaurant Las Mananitas
# 82   135034  22.140517 -101.021422      Michiko Restaurant Japones
# 26   132755  22.153324 -101.019546            La Estrella de Dimas
# 70   135013  18.917441  -99.165945                       Giovannis
# 16   132667  23.752697  -99.163359  little pizza Emilio Portes Gil
#
#                city       state country            alcohol smoking_area  \
# 62       Cuernavaca     Morelos  Mexico          Wine-Beer         none
# 82  San Luis Potosi         SLP  Mexico  No_Alcohol_Served         none
# 26  San Luis Potosi      S.L.P.  Mexico  No_Alcohol_Served         none
# 70         Jiutepec     Morelos  Mexico  No_Alcohol_Served         none
# 16        victoria   tamaulipas       ?  No_Alcohol_Served         none
#
#    dress_code     accessibility   price Rambience franchise    area  \
# 62     formal  no_accessibility    high  familiar         f  closed
# 82   informal  no_accessibility  medium  familiar         f  closed
# 26   informal         partially  medium  familiar         f  closed
# 70   informal  no_accessibility     low  familiar         f  closed
# 16   informal        completely     low  familiar         t  closed
#
#    other_services  userID_count  rating_mean  food_rating_mean  \
# 62           none             8        5.000               5.0
# 82           none             5        5.000               5.0
# 26        variety             5        4.500               5.0
# 70           none             4        4.375               5.0
# 16           none             4        3.125               5.0
#
#     service_rating_mean
# 62                5.000
# 82                4.000
# 26                4.000
# 70                4.375
# 16                3.125

# %%
cuisine_df = pd.read_csv('./data/chefmozcuisine.csv') # placeID is not unique
cuisine_df.head(n=10)
# Out:
#    placeID           Rcuisine
# 0   135110            Spanish
# 1   135109            Italian
# 2   135107     Latin_American
# 3   135106            Mexican
# 4   135105          Fast_Food
# 5   135104            Mexican
# 6   135103            Burgers
# 7   135103  Dessert-Ice_Cream
# 8   135103          Fast_Food
# 9   135103           Hot_Dogs

# %%
cuisine_top_5 = cuisine_df.groupby('Rcuisine', as_index=False)\
        .agg('count')\
        .rename(columns={'placeID': 'counts', 'Rcuisine':'cuisine'})\
        .sort_values('counts', ascending=0)\
        .head(n=5)\
        .reset_index()
        
cuisine_top_5
# Out:
#    index        cuisine  counts
# 0     41        Mexican     239
# 1     34  International      62
# 2      2       American      59
# 3     23  Dutch-Belgian      55
# 4     35        Italian      42

# %%
cuisine_top_5 = cuisine_top_5.drop(['index'], axis=1)
cuisine_top_5
# Out:
#          cuisine  counts
# 0        Mexican     239
# 1  International      62
# 2       American      59
# 3  Dutch-Belgian      55
# 4        Italian      42

# %%
import matplotlib.pyplot as plt
import numpy as np

height = tuple(cuisine_top_5.counts)
bars = tuple(cuisine_top_5.cuisine)
y_pos = np.arange(len(bars))

plt.bar(y_pos,height)
plt.xticks(y_pos, bars, )
plt.yticks()
plt.show()

# %%
gb = cuisine_df.groupby('placeID').apply(lambda x: ', '.join(x['Rcuisine']))
gb
# Out:
# placeID
# 132001                                        Dutch-Belgian
# 132002                                              Seafood
# 132003                                        International
# 132004                                              Seafood
# 132005                                      French, Seafood
# 132006                                        Dutch-Belgian
# 132007                                        Mediterranean
# 132008                                        International
# 132009                                        International
# 132010                         Mediterranean, Dutch-Belgian
# 132012                                French, Dutch-Belgian
# 132013                                        International
# 132014                                        Dutch-Belgian
# 132015                                        Dutch-Belgian
# 132016                                        International
# 132017                                        Dutch-Belgian
# 132018                                        Dutch-Belgian
# 132019                                        Dutch-Belgian
# 132020                                        International
# 132021                                        Dutch-Belgian
# 132022                                        Dutch-Belgian
# 132023                                French, Dutch-Belgian
# 132024                        Seafood, Continental-European
# 132025                                        Dutch-Belgian
# 132026                                        Dutch-Belgian
# 132028                                     Italian, Seafood
# 132030                                French, Dutch-Belgian
# 132031                          Family, German, Fine_Dining
# 132083                                        International
# 132087                                     Cafe-Coffee_Shop
#                                 ...
# 135061                                         Contemporary
# 135069                                                  Bar
# 135071                                 Bar, Bar_Pub_Brewery
# 135072                                             Japanese
# 135073                                 Bar, Bar_Pub_Brewery
# 135074                                         Contemporary
# 135075                                              Seafood
# 135079                                              Chinese
# 135085                                            Fast_Food
# 135086                                   Burgers, Fast_Food
# 135088                                            Cafeteria
# 135089                                              Seafood
# 135090                                              Mexican
# 135091                                      Japanese, Sushi
# 135092                                   Cafeteria, Mexican
# 135093                                              Mexican
# 135094                                              Mexican
# 135097    Cafe-Coffee_Shop, Cafeteria, Contemporary, Del...
# 135098     Brazilian, International, Latin_American, Steaks
# 135099    Asian, Dessert-Ice_Cream, International, Mongo...
# 135100                                      Mexican, Steaks
# 135101                                      Mexican, Steaks
# 135102                      Latin_American, Mexican, Steaks
# 135103      Burgers, Dessert-Ice_Cream, Fast_Food, Hot_Dogs
# 135104                                              Mexican
# 135105                                            Fast_Food
# 135106                                              Mexican
# 135107                                       Latin_American
# 135109                                              Italian
# 135110                                              Spanish
# Length: 769, dtype: object

# %%
df=gb.to_frame()
df=df.reset_index()
df.head()
# Out:
#    placeID                0
# 0   132001    Dutch-Belgian
# 1   132002          Seafood
# 2   132003    International
# 3   132004          Seafood
# 4   132005  French, Seafood

# %%
df = df.rename(columns={0: "cuisines"})
df.head()
# Out:
#    placeID         cuisines
# 0   132001    Dutch-Belgian
# 1   132002          Seafood
# 2   132003    International
# 3   132004          Seafood
# 4   132005  French, Seafood

# %%
l = df.cuisines.tolist()
text = ' '.join(l)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud = WordCloud(width=480, height=480, margin=0, max_words=20, max_font_size=70, min_font_size=10).generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
by_service = agg_groupby.sort_values(['service_rating_mean', 'rating_mean'], ascending=False)
by_service.head(n=5)
